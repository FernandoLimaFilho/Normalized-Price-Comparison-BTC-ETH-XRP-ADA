# %%
"""
Importando as bibliotecas
"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mticker
from matplotlib.ticker import AutoMinorLocator, MaxNLocator
from matplotlib.font_manager import FontProperties
"""
Normalização dos preços
"""
from sklearn.preprocessing import MinMaxScaler

# %%
"""
Importando os dados
"""
Data_XRP = pd.read_csv("/content/XRP Historical Data (1).csv")
Data_XRP.head()
# Out:
#          Date   Price    Open    High     Low     Vol. Change %
# 0  03/23/2025  2.4108  2.3710  2.4241  2.3656  215.16M    1.68%
# 1  03/22/2025  2.3710  2.3802  2.4162  2.3599  189.14M   -0.38%
# 2  03/21/2025  2.3801  2.4356  2.4653  2.3588  399.74M   -2.29%
# 3  03/20/2025  2.4358  2.5461  2.5549  2.3923  610.64M   -4.23%
# 4  03/19/2025  2.5434  2.2815  2.5806  2.2659    1.11B   11.30%

# %%
"""
Transformando a coluna "Date" em datetime
"""
Data_XRP["Date"] = pd.to_datetime(Data_XRP["Date"], format="%m/%d/%Y")

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_XRP["Date"], Data_XRP["Price"], color = "orange")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Price (US$)", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Price history of XRP", fontdict=font1)
"""
Mostrar o gráfico
"""
plt.show()

# %%
Data_BTC = pd.read_csv("/content/Bitcoin Historical Data (1).csv")
Data_BTC.head()
# Out:
#          Date     Price      Open      High       Low    Vol. Change %
# 0  03/23/2025  84,766.0  83,840.2  85,008.4  83,812.7  22.27K    1.10%
# 1  03/22/2025  83,840.5  84,076.6  84,526.3  83,688.2  20.84K   -0.28%
# 2  03/21/2025  84,073.3  84,208.7  84,831.0  83,215.9  42.80K   -0.16%
# 3  03/20/2025  84,208.1  86,841.3  87,419.0  83,656.1  69.86K   -3.03%
# 4  03/19/2025  86,841.0  82,719.1  86,990.6  82,557.5  84.61K    4.98%

# %%
Data_BTC["Date"] = pd.to_datetime(Data_BTC["Date"], format="%m/%d/%Y")

# %%
Data_BTC["Price"] = Data_BTC["Price"].str.replace(",", "")
Data_BTC["Price"] = Data_BTC.Price.astype(float)

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Price (US$)", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Price history of BTC", fontdict=font1)
"""
Mostrar o gráfico
"""
plt.show()

# %%
Norm = MinMaxScaler()
Data_BTC["Price"] = Data_BTC["Price"].values.reshape(-1, 1)
Data_BTC["Price"] = Norm.fit_transform(Data_BTC[["Price"]])
Data_BTC
# Out:
#            Date     Price      Open      High       Low    Vol. Change %
# 0    2025-03-23  0.797794  83,840.2  85,008.4  83,812.7  22.27K    1.10%
# 1    2025-03-22  0.789046  84,076.6  84,526.3  83,688.2  20.84K   -0.28%
# 2    2025-03-21  0.791246  84,208.7  84,831.0  83,215.9  42.80K   -0.16%
# 3    2025-03-20  0.792520  86,841.3  87,419.0  83,656.1  69.86K   -3.03%
# 4    2025-03-19  0.817409  82,719.1  86,990.6  82,557.5  84.61K    4.98%
# ...         ...       ...       ...       ...       ...     ...      ...
# 3364 2016-01-05  0.000597     433.3     435.3     428.9  45.03K   -0.49%
# 3365 2016-01-04  0.000617     430.7     435.3     428.6  53.01K    0.61%
# 3366 2016-01-03  0.000593     433.7     434.1     423.1  54.83K   -0.70%
# 3367 2016-01-02  0.000621     434.0     437.4     430.7  33.57K   -0.06%
# 3368 2016-01-01  0.000624     430.0     438.0     425.9  46.97K    0.94%
#
# [3369 rows x 7 columns]

# %%
Data_XRP["Price"] = Data_XRP["Price"].values.reshape(-1, 1)
Data_XRP["Price"] = Norm.fit_transform(Data_XRP[["Price"]])
Data_XRP
# Out:
#            Date     Price    Open    High     Low     Vol. Change %
# 0    2025-03-23  0.732129  2.3710  2.4241  2.3656  215.16M    1.68%
# 1    2025-03-22  0.720022  2.3802  2.4162  2.3599  189.14M   -0.38%
# 2    2025-03-21  0.722790  2.4356  2.4653  2.3588  399.74M   -2.29%
# 3    2025-03-20  0.739734  2.5461  2.5549  2.3923  610.64M   -4.23%
# 4    2025-03-19  0.772465  2.2815  2.5806  2.2659    1.11B   11.30%
# ...         ...       ...     ...     ...     ...      ...      ...
# 3364 2016-01-05  0.000304  0.0051  0.0054  0.0050      NaN   -1.96%
# 3365 2016-01-04  0.000335  0.0052  0.0054  0.0051      NaN   -1.92%
# 3366 2016-01-03  0.000365  0.0051  0.0054  0.0050    0.02K    1.46%
# 3367 2016-01-02  0.000335  0.0051  0.0051  0.0050    0.50K   -6.82%
# 3368 2016-01-01  0.000456  0.0052  0.0055  0.0051      NaN    5.67%
#
# [3369 rows x 7 columns]

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_XRP["Date"], Data_XRP["Price"], color = "black")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Price history of BTC vs XRP", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "XRP"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
Data_ETH = pd.read_csv("/content/Ethereum Historical Data.csv")
Data_ETH
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     03/23/2025  2,009.14  1,980.78  2,019.59  1,977.07  249.72K    1.43%
# 1     03/22/2025  1,980.80  1,965.74  2,005.80  1,965.45  185.64K    0.77%
# 2     03/21/2025  1,965.58  1,983.94  1,996.73  1,938.55  291.89K   -0.91%
# 3     03/20/2025  1,983.57  2,056.11  2,066.45  1,952.95  433.71K   -3.55%
# 4     03/19/2025  2,056.62  1,931.79  2,069.43  1,927.77  743.84K    6.42%
# ...          ...       ...       ...       ...       ...      ...      ...
# 3296  03/14/2016     12.50     15.07     15.07     11.40   92.18K  -17.05%
# 3297  03/13/2016     15.07     12.92     15.07     12.92    1.30K   16.64%
# 3298  03/12/2016     12.92     11.95     13.45     11.95    0.83K    8.12%
# 3299  03/11/2016     11.95     11.75     11.95     11.75    0.18K    1.70%
# 3300  03/10/2016     11.75     11.20     11.85     11.07    0.00K    4.91%
#
# [3301 rows x 7 columns]

# %%
Data_ETH["Date"] = pd.to_datetime(Data_ETH["Date"], format="%m/%d/%Y")

# %%
Data_ETH["Price"] = Data_ETH["Price"].str.replace(",", "")
Data_ETH["Price"] = Data_ETH.Price.astype(float)

# %%
Data_ETH["Price"] = Data_ETH["Price"].values.reshape(-1, 1)
Data_ETH["Price"] = Norm.fit_transform(Data_ETH[["Price"]])
Data_ETH
# Out:
#            Date     Price      Open      High       Low     Vol. Change %
# 0    2025-03-23  0.417029  1,980.78  2,019.59  1,977.07  249.72K    1.43%
# 1    2025-03-22  0.411127  1,965.74  2,005.80  1,965.45  185.64K    0.77%
# 2    2025-03-21  0.407957  1,983.94  1,996.73  1,938.55  291.89K   -0.91%
# 3    2025-03-20  0.411704  2,056.11  2,066.45  1,952.95  433.71K   -3.55%
# 4    2025-03-19  0.426917  1,931.79  2,069.43  1,927.77  743.84K    6.42%
# ...         ...       ...       ...       ...       ...      ...      ...
# 3296 2016-03-14  0.001208     15.07     15.07     11.40   92.18K  -17.05%
# 3297 2016-03-13  0.001743     12.92     15.07     12.92    1.30K   16.64%
# 3298 2016-03-12  0.001295     11.95     13.45     11.95    0.83K    8.12%
# 3299 2016-03-11  0.001093     11.75     11.95     11.75    0.18K    1.70%
# 3300 2016-03-10  0.001052     11.20     11.85     11.07    0.00K    4.91%
#
# [3301 rows x 7 columns]

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_ETH["Date"], Data_ETH["Price"], color = "darkblue")
axs.plot(Data_XRP["Date"], Data_XRP["Price"], color = "black")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. ETH vs. XRP", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "ETH", "XRP"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
Data_ADA = pd.read_csv("/content/Cardano Historical Data.csv")
Data_ADA
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     03/23/2025  0.7112  0.7014  0.7158  0.7008  141.88M    1.40%
# 1     03/22/2025  0.7014  0.7050  0.7160  0.6975  110.49M   -0.49%
# 2     03/21/2025  0.7048  0.7179  0.7273  0.7007  159.73M   -1.81%
# 3     03/20/2025  0.7178  0.7437  0.7551  0.7125  233.04M   -3.47%
# 4     03/19/2025  0.7437  0.7018  0.7467  0.7006  281.11M    5.96%
# ...          ...     ...     ...     ...     ...      ...      ...
# 2634  01/04/2018  1.1043  1.1000  1.3500  1.0500   19.60M    2.25%
# 2635  01/03/2018  1.0800  0.9782  1.0900  0.8882   20.23M   41.73%
# 2636  01/02/2018  0.7620  0.7022  0.8000  0.6750   10.97M    8.52%
# 2637  01/01/2018  0.7022  0.7100  0.7150  0.6320   17.95M   -1.10%
# 2638  12/31/2017  0.7100  0.5900  0.7400  0.5900   17.22M   20.34%
#
# [2639 rows x 7 columns]

# %%
Data_ADA["Date"] = pd.to_datetime(Data_ADA["Date"], format="%m/%d/%Y")

# %%
Data_ADA["Price"] = Data_ADA["Price"].values.reshape(-1, 1)
Data_ADA["Price"] = Norm.fit_transform(Data_ADA[["Price"]])
Data_ADA
# Out:
#            Date     Price    Open    High     Low     Vol. Change %
# 0    2025-03-23  0.233855  0.7014  0.7158  0.7008  141.88M    1.40%
# 1    2025-03-22  0.230523  0.7050  0.7160  0.6975  110.49M   -0.49%
# 2    2025-03-21  0.231679  0.7179  0.7273  0.7007  159.73M   -1.81%
# 3    2025-03-20  0.236098  0.7437  0.7551  0.7125  233.04M   -3.47%
# 4    2025-03-19  0.244901  0.7018  0.7467  0.7006  281.11M    5.96%
# ...         ...       ...     ...     ...     ...      ...      ...
# 2634 2018-01-04  0.367471  1.1000  1.3500  1.0500   19.60M    2.25%
# 2635 2018-01-03  0.359211  0.9782  1.0900  0.8882   20.23M   41.73%
# 2636 2018-01-02  0.251122  0.7022  0.8000  0.6750   10.97M    8.52%
# 2637 2018-01-01  0.230795  0.7100  0.7150  0.6320   17.95M   -1.10%
# 2638 2017-12-31  0.233447  0.5900  0.7400  0.5900   17.22M   20.34%
#
# [2639 rows x 7 columns]

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_ETH["Date"], Data_ETH["Price"], color = "darkblue")
axs.plot(Data_XRP["Date"], Data_XRP["Price"], color = "black")
axs.plot(Data_ADA["Date"], Data_ADA["Price"], color = "red")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. ETH vs. XRP vs. ADA", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "ETH", "XRP", "ADA"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_ADA["Date"], Data_ADA["Price"], color = "red")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. ADA", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "ADA"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_XRP["Date"], Data_XRP["Price"], color = "black")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. XRP", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "XRP"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_ETH["Date"], Data_ETH["Price"], color = "darkblue")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. ETH", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "ETH"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
Data_SEP500 = pd.read_csv("/content/S&P 500 Historical Data.csv")
Data_SEP500
# Out:
#             Date     Price      Open      High       Low Vol. Change %
# 0     03/21/2025  5,667.56  5,630.73  5,670.84  5,603.10  NaN    0.08%
# 1     03/20/2025  5,662.89  5,646.92  5,711.15  5,632.33  NaN   -0.22%
# 2     03/19/2025  5,675.29  5,632.37  5,715.33  5,622.20  NaN    1.08%
# 3     03/18/2025  5,614.66  5,654.53  5,654.53  5,597.76  NaN   -1.07%
# 4     03/17/2025  5,675.12  5,635.60  5,703.52  5,631.12  NaN    0.64%
# ...          ...       ...       ...       ...       ...  ...      ...
# 2313  01/08/2016  1,922.00  1,946.00  1,960.40  1,918.50  NaN   -1.09%
# 2314  01/07/2016  1,943.10  1,985.30  1,985.30  1,938.80  NaN   -2.37%
# 2315  01/06/2016  1,990.30  2,011.70  2,011.70  1,979.00  NaN   -1.31%
# 2316  01/05/2016  2,016.70  2,013.80  2,021.90  2,004.20  NaN    0.20%
# 2317  01/04/2016  2,012.70  2,038.20  2,038.20  1,989.70  NaN   -1.53%
#
# [2318 rows x 7 columns]

# %%
Data_SEP500["Date"] = pd.to_datetime(Data_SEP500["Date"], format="%m/%d/%Y")

# %%
Data_SEP500["Price"] = Data_SEP500["Price"].str.replace(",", "")
Data_SEP500["Price"] = Data_SEP500.Price.astype(float)

# %%
Data_SEP500["Price"] = Data_SEP500["Price"].values.reshape(-1, 1)
Data_SEP500["Price"] = Norm.fit_transform(Data_SEP500[["Price"]])
Data_SEP500
# Out:
#            Date     Price      Open      High       Low Vol. Change %
# 0    2025-03-21  0.889552  5,630.73  5,670.84  5,603.10  NaN    0.08%
# 1    2025-03-20  0.888469  5,646.92  5,711.15  5,632.33  NaN   -0.22%
# 2    2025-03-19  0.891343  5,632.37  5,715.33  5,622.20  NaN    1.08%
# 3    2025-03-18  0.877292  5,654.53  5,654.53  5,597.76  NaN   -1.07%
# 4    2025-03-17  0.891304  5,635.60  5,703.52  5,631.12  NaN    0.64%
# ...         ...       ...       ...       ...       ...  ...      ...
# 2313 2016-01-08  0.021529  1,946.00  1,960.40  1,918.50  NaN   -1.09%
# 2314 2016-01-07  0.026419  1,985.30  1,985.30  1,938.80  NaN   -2.37%
# 2315 2016-01-06  0.037358  2,011.70  2,011.70  1,979.00  NaN   -1.31%
# 2316 2016-01-05  0.043476  2,013.80  2,021.90  2,004.20  NaN    0.20%
# 2317 2016-01-04  0.042549  2,038.20  2,038.20  1,989.70  NaN   -1.53%
#
# [2318 rows x 7 columns]

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_SEP500["Date"], Data_SEP500["Price"], color = "black")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. S&P 500", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "S&P 500"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
Data_BOVA = pd.read_csv("/content/Bovespa Historical Data.csv")

# %%
Data_BOVA["Date"] = pd.to_datetime(Data_BOVA["Date"], format="%m/%d/%Y")

# %%
Data_BOVA["Price"] = Data_BOVA["Price"].str.replace(",", "")
Data_BOVA["Price"] = Data_BOVA.Price.astype(float)

# %%
Data_BOVA["Price"] = Data_BOVA["Price"].values.reshape(-1, 1)
Data_BOVA["Price"] = Norm.fit_transform(Data_BOVA[["Price"]])
Data_BOVA
# Out:
#            Date     Price     Open     High      Low    Vol. Change %
# 0    2025-03-21  0.949933  132,005  132,588  131,776  14.19B    0.30%
# 1    2025-03-20  0.946027  132,505  132,713  131,813  14.19B   -0.42%
# 2    2025-03-19  0.951566  131,476  132,984  131,451  12.20B    0.79%
# 3    2025-03-18  0.941220  130,832  131,834  130,722  10.99B    0.49%
# 4    2025-03-17  0.934800  128,959  131,313  128,957  11.06B    1.46%
# ...         ...       ...      ...      ...      ...     ...      ...
# 2283 2016-01-08  0.031198   40,695   41,218   40,463   3.32M   -0.20%
# 2284 2016-01-07  0.032029   41,772   41,772   40,695   4.16M   -2.58%
# 2285 2016-01-06  0.042826   42,410   42,410   41,590   4.06M   -1.52%
# 2286 2016-01-05  0.049295   42,139   42,534   42,137   2.64M    0.66%
# 2287 2016-01-04  0.046511   43,349   43,349   42,125   3.07M   -2.79%
#
# [2288 rows x 7 columns]

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_BTC["Date"], Data_BTC["Price"], color = "orange")
axs.plot(Data_SEP500["Date"], Data_SEP500["Price"], color = "black")
axs.plot(Data_BOVA["Date"], Data_BOVA["Price"], color = "green")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: BTC vs. S&P 500 vs. Ibovespa", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["BTC", "S&P 500", "Ibovespa"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
tabela_de_precos = pd.concat([Data_SEP500[['Price']], Data_BOVA[["Price"]] ,Data_BTC[['Price']], Data_XRP[['Price']], Data_ETH[['Price']], Data_ADA[['Price']]], axis=1)
tabela_de_precos.columns = ['SEP500', "Ibovespa",'BTC', "XRP", "ETH", "ADA"]
tabela_de_precos
# Out:
#         SEP500  Ibovespa       BTC       XRP       ETH       ADA
# 0     0.889552  0.949933  0.797794  0.732129  0.417029  0.233855
# 1     0.888469  0.946027  0.789046  0.720022  0.411127  0.230523
# 2     0.891343  0.951566  0.791246  0.722790  0.407957  0.231679
# 3     0.877292  0.941220  0.792520  0.739734  0.411704  0.236098
# 4     0.891304  0.934800  0.817409  0.772465  0.426917  0.244901
# ...        ...       ...       ...       ...       ...       ...
# 3364       NaN       NaN  0.000597  0.000304       NaN       NaN
# 3365       NaN       NaN  0.000617  0.000335       NaN       NaN
# 3366       NaN       NaN  0.000593  0.000365       NaN       NaN
# 3367       NaN       NaN  0.000621  0.000335       NaN       NaN
# 3368       NaN       NaN  0.000624  0.000456       NaN       NaN
#
# [3369 rows x 6 columns]

# %%
correlacao = tabela_de_precos['SEP500'].corr(tabela_de_precos['BTC'])
print(correlacao)
# Out:
# 0.7298074968100777

# %%
correlacao2 = tabela_de_precos['Ibovespa'].corr(tabela_de_precos['BTC'])
print(correlacao2)
# Out:
# 0.6984241655487003

# %%
Data_gold = pd.read_csv("/content/Gold Futures Historical Data.csv")
Data_gold.head()
# Out:
#          Date     Price      Open      High       Low    Vol. Change %
# 0  03/27/2025  3,089.41  3,054.77  3,094.85  3,054.77  76.70K    1.22%
# 1  03/26/2025  3,052.30  3,054.10  3,064.90  3,046.50   2.48K   -0.07%
# 2  03/25/2025  3,054.30  3,046.00  3,070.70  3,039.20  89.68K    0.34%
# 3  03/24/2025  3,044.00  3,054.70  3,066.40  3,036.00  96.48K   -0.14%
# 4  03/21/2025  3,048.40  3,080.10  3,082.20  3,031.20  46.90K   -0.75%

# %%
Data_gold["Date"] = pd.to_datetime(Data_gold["Date"], format = "%m/%d/%Y")

# %%
Data_gold["Price"] = Data_gold["Price"].str.replace(",", "")
Data_gold["Price"] = Data_gold.Price.astype(float)

# %%
Data_gold["Price"] = Data_gold["Price"].values.reshape(-1, 1)
Data_gold["Price"] = Norm.fit_transform(Data_gold[["Price"]])
Data_gold
# Out:
#            Date     Price      Open      High       Low     Vol. Change %
# 0    2025-03-27  1.000000  3,054.77  3,094.85  3,054.77   76.70K    1.22%
# 1    2025-03-26  0.981591  3,054.10  3,064.90  3,046.50    2.48K   -0.07%
# 2    2025-03-25  0.982583  3,046.00  3,070.70  3,039.20   89.68K    0.34%
# 3    2025-03-24  0.977473  3,054.70  3,066.40  3,036.00   96.48K   -0.14%
# 4    2025-03-21  0.979656  3,080.10  3,082.20  3,031.20   46.90K   -0.75%
# ...         ...       ...       ...       ...       ...      ...      ...
# 2366 2016-01-08  0.012055  1,108.80  1,113.10  1,091.80  193.45K   -0.89%
# 2367 2016-01-07  0.016966  1,093.70  1,109.90  1,091.10  217.27K    1.46%
# 2368 2016-01-06  0.009078  1,076.80  1,094.90  1,074.40  191.80K    1.25%
# 2369 2016-01-05  0.002381  1,073.50  1,081.50  1,071.90  104.64K    0.30%
# 2370 2016-01-04  0.000794  1,061.50  1,083.00  1,061.00  159.79K    1.41%
#
# [2371 rows x 7 columns]

# %%
"""
Criação da primeira fonte de texto para colocar como fonte dos labels
"""
font1 = {"family": "serif", "weight": "bold", "color": "black", "size": 14}
"""
Criação da segunda fonte de texto para colocar como fonte da legenda
"""
font2 = FontProperties(family = "serif",
                       weight = "bold",
                       size = 14)
"""
Cria um "lugar" com size (9, 7) para alocar a figura
"""
fig, axs = plt.subplots(figsize = (16, 7))
"""
Plota um scatter entre o total de casos (cumulativo) e total de mortes (cumulativo)
"""
axs.plot(Data_SEP500["Date"], Data_SEP500["Price"], color = "black")
axs.plot(Data_gold["Date"], Data_gold["Price"], color = "yellow")
axs.grid(False)
"""
Definindo a "grossura" e a cor do eixos
"""
for axis in ["left", "right", "top", "bottom"]:
    axs.spines[axis].set_linewidth(2)
    axs.spines[axis].set_color("black")
"""
Trabalha com os ticks do gráfico
"""
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(axis = "both", direction = "in", labelcolor = "black", labelsize = 14, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "major", direction = "in", color = "black", length = 5.4, width = 2.5, left = True, bottom = True, top = True, right = True)
axs.tick_params(which = "minor", direction = "in", color = "black", length=4, width = 2, left = True, bottom = True, top = True, right = True)
"""
Descrição para cada eixo
"""
axs.set_xlabel("Data", fontdict = font1)
axs.set_ylabel("Normalized Price", fontdict = font1)
"""
plt.rcParams["axes.labelweight"] = "bold" mostra em negrito os números nos eixos.
"""
plt.rcParams["axes.labelweight"] = "bold"
"""
Definindo um fundo branco para a imagem
"""
fig.patch.set_facecolor("white")
Cor_fundo = plt.gca()
Cor_fundo.set_facecolor("white")
Cor_fundo.patch.set_alpha(1)
"""
Título
"""
plt.title("Normalized Price Comparison: S&P 500 vs. Gold", fontdict=font1)
"""
Mostrar o gráfico
"""
"""
Legenda
"""
plt.legend(["S&P 500", "Gold"], prop = font2, frameon=False)
"""
Mostrar o gráfico
"""
plt.show()

# %%
tabela_de_precos = pd.concat([Data_SEP500[['Price']], Data_BOVA[["Price"]] ,Data_BTC[['Price']],
                              Data_XRP[['Price']], Data_ETH[['Price']], Data_ADA[['Price']], Data_gold[["Price"]]], axis=1)
tabela_de_precos.columns = ['SEP500', "Ibovespa",'BTC', "XRP", "ETH", "ADA", "Gold"]
tabela_de_precos
# Out:
#         SEP500  Ibovespa       BTC       XRP       ETH       ADA      Gold
# 0     0.889552  0.949933  0.797794  0.732129  0.417029  0.233855  1.000000
# 1     0.888469  0.946027  0.789046  0.720022  0.411127  0.230523  0.981591
# 2     0.891343  0.951566  0.791246  0.722790  0.407957  0.231679  0.982583
# 3     0.877292  0.941220  0.792520  0.739734  0.411704  0.236098  0.977473
# 4     0.891304  0.934800  0.817409  0.772465  0.426917  0.244901  0.979656
# ...        ...       ...       ...       ...       ...       ...       ...
# 3364       NaN       NaN  0.000597  0.000304       NaN       NaN       NaN
# 3365       NaN       NaN  0.000617  0.000335       NaN       NaN       NaN
# 3366       NaN       NaN  0.000593  0.000365       NaN       NaN       NaN
# 3367       NaN       NaN  0.000621  0.000335       NaN       NaN       NaN
# 3368       NaN       NaN  0.000624  0.000456       NaN       NaN       NaN
#
# [3369 rows x 7 columns]

# %%
correlacao_4 = tabela_de_precos['SEP500'].corr(tabela_de_precos['Gold'])
print(correlacao_4)
# Out:
# 0.9284920517370844
